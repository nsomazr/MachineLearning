# %% [markdown]
# <h1 style="text-align:center;">LINEAR REGRESSION</h1>
# <br>
# <br>
# <h4>Types of Linear Regression</h4>
#
#    -  Simple linear regression
#    -  Multiple linear regression
#    -  Polynomial linear regression

# %% [markdown]
# <h3 style="text-align:center;"><u>SIMPLE LINEAR REGRESSION</u></h3>

# %% [markdown]
# **Dataset :**
#
# Assume that you have recorded the diameters and prices of pizza that you have previously eaten.
# <br>
# <h6>Train set</h6>
# <br>
#
# **Training instance**      |    **Diameter (in inches)** | **Price(in dillars)**
# ---------------------------|-------------------------------|----------------------------
# 1.                         |            6                  |           7
# 2.                         |            8                  |           9
# 3.                         |            10                 |           13
# 4.                         |            14                 |           17.5
# 5.                         |            18                 |           18
#
# <br>
# <h6>Test set </h6>
# <br>
#
# **Training instance**      |    **Diameter (in inches)** | **Price(in dillars)**
# ---------------------------|-------------------------------|----------------------------
# 1.                         |            8                  |           11
# 2.                         |            9                  |           8.5
# 3.                         |            11                 |           15
# 4.                         |            16                 |           18
# 5.                         |            12                 |           11
#
# <br>
#
# <h3>Implementation concept</h3>

# %% [markdown]
# <h5>Plot the graph for the dataset : </h5>

# %%
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
diameter = np.array([6,8,10,14,18])
price = np.array([7,9,13,17.5,18])

# %%
#plot
plt.plot(diameter,price,'r.',label="data point",markersize=15)
plt.title("Relationship between diameter and price")
plt.xlabel("$Diameter(in)$")
plt.ylabel("Price")
plt.grid(True)
plt.legend()
plt.show()

# %%
#initialize weight and bias to zero
w = 100
b = 0

# %%
#define a function to perform prediction
def predict(x):
    return (w*x + b)

# %%
# define a function to calculate error(loss)
from math import pow
def loss(x,y):
    return (pow((predict(x)-y),2))/2

# %%
#define a function to calculate gradient of Error wrt Weight
def gradient_weight(x,y):
    return x*(predict(x)-y)

# %%
#define a function to calculate the gradient of Error wrt bias
def gradient_bias(x,y):
    return (predict(x)-y)

# %%
#create list to store sum of loss, weight and bias
weight_list = []
bias_list = []
loss_list = []

# %%
#initialize the learning rate (step size)
lr = 0.001

# %%
#prediction before training the model
print("[8,9,11,16,12] diameter pizza costs : ",predict(np.array([8,9,11,16,12]))," dollars")
# Out:
# [8,9,11,16,12] diameter pizza costs :  [ 800  900 1100 1600 1200]  dollars

# %%
#train the model to get the optimal values of Weight and bias
for epoch in np.arange(1000):
    print("Epoch number:  ",epoch)
    #initialize the sum of loss
    loss_sum = 0
    #for each epoch pass through all datapoints
    for x,y in zip(diameter,price):
        #update weight
        w = w - lr*gradient_weight(x,y)
        #update bias
        b = b- lr*gradient_bias(x,y)
        #sum loss
        loss_sum += loss(x,y)
        #append the sum to the list
        loss_list.append(loss_sum)
        #append weight to the list
        weight_list.append(w)
        #append bias to the list
        bias_list.append(b)
        print("Weight gradient : ",gradient_weight(x,y))
        print("Bias gradient : ",gradient_bias(x,y))
        print("Weight : ",w)
        print("Bias : ", b)
    print("Mean loss : ", loss_sum/diameter.size,"\n");
# Out:
# Epoch number:   0
# Weight gradient :  3426.4820879999997
# Bias gradient :  571.080348
# Weight :  96.442
# Bias :  -0.5716519999999999
# Weight gradient :  5699.883448786176
# Bias gradient :  712.485431098272
# Weight :  90.346285216
# Bias :  -1.284850629728
# Weight gradient :  7994.599411758676
# Bias gradient :  799.4599411758676
# Weight :  81.45450520069728
# Bias :  -2.085110831105245
# Weight gradient :  12602.86126329173
# Bias gradient :  900.2043759494093
# Weight :  65.76361373299609
# Bias :  -2.9862163125360848
# Weight gradient :  14134.30100471063
# Bias gradient :  785.2389447061462
# Weight :  44.833954777131005
# Bias :  -3.772241282211907
# Mean loss :  289987.2569705701
#
# Epoch number:   1
# Weight gradient :  1492.1173120862318
# Bias gradient :  248.68621868103864
# Weight :  43.284565852847564
# Bias :  -4.0211764360467805
# Weight gradient :  2492.920647632166
# Bias gradient :  311.61508095402075
# Weight :  40.61852304975369
# Bias :  -4.3331034440087635
# Weight gradient :  3496.169474338272
# Bias gradient :  349.6169474338272
# Weight :  36.73000177921841
# Bias :  -4.683070358356939
# Weight gradient :  5532.829592462265
# Bias gradient :  395.2021137473047
# Weight :  29.8414844155086
# Bias :  -5.078668069815702
# Weight gradient :  6248.924869499289
# Bias gradient :  347.1624927499605
# Weight :  20.588259490140494
# Bias :  -5.4261780725684154
# Mean loss :  55788.73110555058
#
# Epoch number:   2
# Weight gradient :  641.9793214307258
# Bias gradient :  106.99655357178764
# Weight :  19.921639216930846
# Bias :  -5.533281729797432
# Weight gradient :  1083.4761013962438
# Bias gradient :  135.43451267453048
# Weight :  18.76292056088565
# Bias :  -5.66885181255472
# Weight gradient :  1519.1225409825495
# Bias gradient :  151.91225409825495
# Weight :  17.073317022922634
# Bias :  -5.8209161309713915
# Weight gradient :  2425.5533764122565
# Bias gradient :  173.25381260087545
# Weight :  14.053439712263398
# Bias :  -5.994343370812108
# Weight gradient :  2783.291331993334
# Bias gradient :  154.6272962218519
# Weight :  9.932023426164676
# Bias :  -6.14912544911226
# Mean loss :  10679.458696246036
#
# Epoch number:   3
# Weight gradient :  268.35777298456964
# Bias gradient :  44.726295497428275
# Weight :  9.653365335517421
# Bias :  -6.193896515676252
# Weight gradient :  464.0387966495023
# Bias gradient :  58.004849581187784
# Weight :  9.157101126169715
# Bias :  -6.2519594281699336
# Weight gradient :  650.2205950352432
# Bias gradient :  65.02205950352432
# Weight :  8.433910607834443
# Bias :  -6.317046574820108
# Weight gradient :  1059.903728285829
# Bias gradient :  75.7074091632735
# Weight :  7.114302780746374
# Bias :  -6.392829767175737
# Weight gradient :  1260.1297085435563
# Bias gradient :  70.00720603019757
# Weight :  5.248339615593712
# Bias :  -6.462907050489248
# Mean loss :  2022.5493004309187
#
# Epoch number:   4
# Weight gradient :  104.16465471589484
# Bias gradient :  17.360775785982472
# Weight :  5.140176831735274
# Bias :  -6.48028520442917
# Weight gradient :  191.80877654018667
# Bias gradient :  23.976097067523334
# Weight :  4.935047796139649
# Bias :  -6.504285301593858
# Weight gradient :  268.3471182042855
# Bias gradient :  26.834711820428552
# Weight :  4.636585869541623
# Bias :  -6.53114687498768
# Weight gradient :  459.6970012825449
# Bias gradient :  32.83550009161035
# Weight :  4.064251095361293
# Bias :  -6.56401524344775
# Weight gradient :  590.6823208337113
# Bias gradient :  32.81568449076174
# Weight :  3.1895860148462933
# Bias :  -6.596863776471536
# Mean loss :  375.13907398312676
#
# Epoch number:   5
# Weight gradient :  32.01508584313827
# Bias gradient :  5.3358476405230455
# Weight :  3.156342100970656
# Bias :  -6.6022049653008885
# Weight gradient :  72.17595822993675
# Bias gradient :  9.021994778742094
# Weight :  3.079153846230941
# Bias :  -6.611235991105435
# Weight gradient :  100.52209951859498
# Bias gradient :  10.0522099518595
# Weight :  2.9673508215189015
# Bias :  -6.6212982633295185
# Weight gradient :  195.9015809275913
# Bias gradient :  13.992970066256522
# Weight :  2.72344823618781
# Bias :  -6.635305240372818
# Weight gradient :  296.44139418562446
# Bias gradient :  16.468966343645803
# Weight :  2.2844865019896705
# Bias :  -6.65179069216826
# Mean loss :  67.79446484500775
#
# Epoch number:   6
# Weight gradient :  0.31854333934676227
# Bias gradient :  0.05309055655779371
# Weight :  2.284155732071052
# Bias :  -6.651843835868518
# Weight gradient :  19.609429272669843
# Bias gradient :  2.4511786590837303
# Weight :  2.263184515905453
# Bias :  -6.654297468159893
# Weight gradient :  26.771131288833647
# Bias gradient :  2.6771131288833647
# Weight :  2.2334090389965064
# Bias :  -6.656977261081698
# Weight gradient :  79.95855535653939
# Bias gradient :  5.711325382609957
# Weight :  2.133858549008335
# Bias :  -6.662694303506733
# Weight gradient :  167.1032999823787
# Bias gradient :  9.283516665687706
# Weight :  1.8864168765927556
# Bias :  -6.6719871129818955
# Mean loss :  13.198094943892897
#
# Epoch number:   7
# Weight gradient :  -13.59894961403609
# Bias gradient :  -2.2664916023393484
# Weight :  1.9005377917133077
# Bias :  -6.669718352619194
# Weight gradient :  -3.4815501144689165
# Bias gradient :  -0.43519376430861456
# Weight :  1.9042611198646096
# Bias :  -6.669282723225492
# Weight gradient :  -5.6344036774933315
# Bias gradient :  -0.5634403677493331
# Weight :  1.9105278351104036
# Bias :  -6.668718718853371
# Weight gradient :  28.99649494815563
# Bias gradient :  2.071178210582545
# Weight :  1.8744264414927116
# Bias :  -6.670791970315415
# Weight gradient :  110.23983004647499
# Bias gradient :  6.124435002581944
# Weight :  1.7111865299147506
# Bias :  -6.676922535883565
# Mean loss :  4.74423261248202
#
# Epoch number:   8
# Weight gradient :  -19.702580310775648
# Bias gradient :  -3.2837633851292747
# Weight :  1.731645350053121
# Bias :  -6.673635485448001
# Weight gradient :  -13.618067765987021
# Bias gradient :  -1.7022584707483777
# Weight :  1.7462091315333053
# Bias :  -6.67193152301482
# Weight gradient :  -19.868673307266782
# Bias gradient :  -1.9868673307266782
# Weight :  1.768307533610123
# Bias :  -6.6699426668279065
# Weight gradient :  6.593499618884167
# Bias gradient :  0.4709642584917262
# Weight :  1.7600984543581297
# Bias :  -6.670414102522092
# Weight gradient :  85.22889086277831
# Bias gradient :  4.7349383812654615
# Weight :  1.6338940089914933
# Bias :  -6.675153780581417
# Mean loss :  4.026987646781668
#
# Epoch number:   9
# Weight gradient :  -22.37203734706329
# Bias gradient :  -3.728672891177215
# Weight :  1.657124747351288
# Bias :  -6.671421375284943
# Weight gradient :  -18.061123190409297
# Bias gradient :  -2.257640398801162
# Weight :  1.676440134523085
# Bias :  -6.6691614749858426
# Weight gradient :  -26.116698326627166
# Bias gradient :  -2.6116698326627166
# Weight :  1.7054877358206348
# Bias :  -6.666547190869063
# Weight gradient :  -3.257814743044392
# Bias gradient :  -0.23270105307459943
# Weight :  1.7095438002719574
# Bias :  -6.666314256882002
# Weight gradient :  74.21711802359204
# Bias gradient :  4.123173223532891
# Weight :  1.5996452656077194
# Bias :  -6.6704415574060585
# Mean loss :  4.287546822590007
#
# Epoch number:   10
# Weight gradient :  -23.532188925715964
# Bias gradient :  -3.9220314876193276
# Weight :  1.6240806853902778
# Bias :  -6.666515599960994
# Weight gradient :  -20.001917495453824
# Bias gradient :  -2.500239686931728
# Weight :  1.645471646324988
# Bias :  -6.664012857531633
# Weight gradient :  -28.85478388098722
# Bias gradient :  -2.885478388098722
# Weight :  1.6775646102678057
# Bias :  -6.661124490776779
# Weight gradient :  -7.592675448017772
# Bias gradient :  -0.542333960572698
# Weight :  1.6870176895261906
# Bias :  -6.660581613939369
# Weight gradient :  69.35797794701783
# Bias gradient :  3.853220997056546
# Weight :  1.5843144271706135
# Bias :  -6.6644386920145005
# Mean loss :  4.5100953187118655
#
# Epoch number:   11
# Weight gradient :  -24.02901244856882
# Bias gradient :  -4.004835408094803
# Weight :  1.6092657399445585
# Bias :  -6.6604298477621535
# Weight gradient :  -20.842979970589766
# Bias gradient :  -2.605372496323721
# Weight :  1.631556171370204
# Bias :  -6.657821867285353
# Weight gradient :  -30.05026104086756
# Bias gradient :  -3.005026104086756
# Weight :  1.6649787729060372
# Bias :  -6.654813833147128
# Weight gradient :  -9.503056986722854
# Bias gradient :  -0.6787897847659181
# Weight :  1.6768103270805137
# Bias :  -6.6541343638931085
# Weight gradient :  67.20292794049244
# Bias gradient :  3.7334959966940247
# Weight :  1.5772981996565032
# Bias :  -6.657871597123033
# Mean loss :  4.625660230600566
#
# Epoch number:   12
# Weight gradient :  -24.234314024283456
# Bias gradient :  -4.039052337380576
# Weight :  1.6024626940516074
# Bias :  -6.65382850169022
# Weight gradient :  -21.200720653592683
# Bias gradient :  -2.6500900816990853
# Weight :  1.6251357096458263
# Bias :  -6.651175758865696
# Weight gradient :  -30.567769593705236
# Bias gradient :  -3.0567769593705236
# Weight :  1.6591338962699007
# Bias :  -6.648115922069529
# Weight gradient :  -10.34787867210958
# Bias gradient :  -0.73913419086497
# Weight :  1.6720172755099736
# Bias :  -6.647376048004599
# Weight gradient :  66.2363373591773
# Bias gradient :  3.6797965199542944
# Weight :  1.5739364471088249
# Bias :  -6.651059528004553
# Mean loss :  4.676802838493121
#
# Epoch number:   13
# Weight gradient :  -24.31150201166417
# Bias gradient :  -4.0519170019440285
# Weight :  1.5991810921809344
# Bias :  -6.6470035550296345
# Weight gradient :  -21.346051055581157
# Bias gradient :  -2.6682563819476446
# Weight :  1.6220095307215916
# Bias :  -6.644332627720377
# Weight gradient :  -30.787317748655596
# Bias gradient :  -3.0787317748655596
# Weight :  1.6562519039266361
# Bias :  -6.641250814131923
# Weight gradient :  -10.7243840163584
# Bias gradient :  -0.7660274297398857
# Weight :  1.6696040421548624
# Bias :  -6.64048401990796
# Weight gradient :  65.79208822851186
# Bias gradient :  3.6551160126951032
# Weight :  1.5721810448550302
# Bias :  -6.644142794695442
# Mean loss :  4.69628839413883
#
# Epoch number:   14
# Weight gradient :  -24.332394192925605
# Bias gradient :  -4.055399032154267
# Weight :  1.5974473840084218
# Bias :  -6.640083336204797
# Weight gradient :  -21.398036473931164
# Bias gradient :  -2.6747545592413955
# Weight :  1.6203314181215211
# Bias :  -6.637405904213565
# Weight gradient :  -30.875918681478183
# Bias gradient :  -3.0875918681478183
# Weight :  1.6546723353515047
# Bias :  -6.634315221662866
# Weight gradient :  -10.895060874164642
# Bias gradient :  -0.778218633868903
# Weight :  1.66823697072589
# Bias :  -6.633536224031365
# Weight gradient :  65.57742243675142
# Bias gradient :  3.643190135375079
# Weight :  1.5711318442432662
# Bias :  -6.637183061003713
# Mean loss :  4.7012255411028
#
# Epoch number:   15
# Weight gradient :  -24.32855439492494
# Bias gradient :  -4.054759065820823
# Weight :  1.596394196216531
# Bias :  -6.633124243120008
# Weight gradient :  -21.409005965925232
# Bias gradient :  -2.676125745740654
# Weight :  1.619289961603633
# Bias :  -6.630445438569717
# Weight gradient :  -30.906974490397694
# Bias gradient :  -3.0906974490397694
# Weight :  1.6536654198289669
# Bias :  -6.627351647329437
# Weight gradient :  -10.9752723653882
# Bias gradient :  -0.7839480260991571
# Weight :  1.6673299206051015
# Bias :  -6.626566914570579
# Weight gradient :  65.46367311180288
# Bias gradient :  3.636870728433493
# Weight :  1.570393230791319
# Bias :  -6.630207425810252
# Mean loss :  4.6996534013334195
#
# Epoch number:   16
# Weight gradient :  -24.313854876435066
# Bias gradient :  -4.052309146072511
# Weight :  1.595640319037693
# Bias :  -6.626151060298668
# Weight gradient :  -21.401958086414574
# Bias gradient :  -2.6752447608018217
# Weight :  1.6185285471016702
# Bias :  -6.623473137615183
# Weight gradient :  -30.91274531038696
# Bias gradient :  -3.091274531038696
# Weight :  1.652910423767655
# Bias :  -6.620378768715244
# Weight gradient :  -11.015720454455014
# Bias gradient :  -0.7868371753182153
# Weight :  1.666625283471208
# Bias :  -6.619591143915126
# Weight gradient :  65.39429129679077
# Bias gradient :  3.6330161831550427
# Weight :  1.569791332217009
# Bias :  -6.623227796751117
# Mean loss :  4.695204149931821
#
# Epoch number:   17
# Weight gradient :  -24.29439247196623
# Bias gradient :  -4.049065411994372
# Weight :  1.5950182110377034
# Bias :  -6.619174678220592
# Weight gradient :  -21.387000667436695
# Bias gradient :  -2.673375083429587
# Weight :  1.617890442957055
# Bias :  -6.6164986270860275
# Weight gradient :  -30.907409429861623
# Bias gradient :  -3.0907409429861623
# Weight :  1.65226638493221
# Bias :  -6.6134047923082635
# Weight gradient :  -11.03868860072538
# Bias gradient :  -0.78847775719467
# Weight :  1.6660098405778125
# Bias :  -6.612615525284045
# Weight gradient :  65.3444237774475
# Bias gradient :  3.6302457654137505
# Weight :  1.5692497316857141
# Bias :  -6.616249404929103
# Mean loss :  4.68949261148575
#
# Epoch number:   18
# Weight gradient :  -24.27284672581922
# Bias gradient :  -4.0454744543032035
# Weight :  1.594454237774603
# Bias :  -6.612199880950822
# Weight gradient :  -21.368576082861033
# Bias gradient :  -2.671072010357629
# Weight :  1.617306765604635
# Bias :  -6.6095261351947086
# Weight gradient :  -30.897198186022905
# Bias gradient :  -3.0897198186022905
# Weight :  1.6516713503961185
# Bias :  -6.606433322563475
# Weight gradient :  -11.053970362554551
# Bias gradient :  -0.7895693116110394
# Weight :  1.6654338322343678
# Bias :  -6.605642962892192
# Weight gradient :  65.30314758272915
# Bias gradient :  3.627952643484953
# Weight :  1.5687348439224922
# Bias :  -6.609274547119905
# Mean loss :  4.6832317883606915
#
# Epoch number:   19
# Weight gradient :  -24.250395287098303
# Bias gradient :  -4.041732547849717
# Weight :  1.593916036824002
# Bias :  -6.605228768793729
# Weight gradient :  -21.348636744071605
# Bias gradient :  -2.6685795930089506
# Weight :  1.6167472406176158
# Bias :  -6.602557517949877
# Weight gradient :  -30.884850239957515
# Bias gradient :  -3.0884850239957515
# Weight :  1.6510980917353528
# Bias :  -6.599465941349281
# Weight gradient :  -11.065870000855845
# Bias gradient :  -0.7904192857754175
# Weight :  1.6648753889341137
# Bias :  -6.598674730853009
# Weight gradient :  65.26566206782499
# Bias gradient :  3.6258701148791666
# Weight :  1.568231908074815
# Bias :  -6.602304230467503
# Mean loss :  4.676735551331721
#
# Epoch number:   20
# Weight gradient :  -24.227555723664462
# Bias gradient :  -4.037925953944077
# Weight :  1.5933893847669267
# Bias :  -6.598262262545637
# Weight gradient :  -21.328040726746885
# Bias gradient :  -2.6660050908433606
# Weight :  1.6161985622422086
# Bias :  -6.595593588781029
# Weight gradient :  -30.871569225533264
# Bias gradient :  -3.0871569225533264
# Weight :  1.650534641905798
# Bias :  -6.592503341611306
# Weight gradient :  -11.076279236490507
# Bias gradient :  -0.7911628026064648
# Weight :  1.6643248988748198
# Bias :  -6.591711386853942
# Weight gradient :  65.22985734342379
# Bias gradient :  3.6238809635235434
# Weight :  1.567734436602749
# Bias :  -6.595338895325938
# Mean loss :  4.6701418836423265
#
# Epoch number:   21
# Weight gradient :  -24.204555498420717
# Bias gradient :  -4.0340925830701195
# Weight :  1.5928680302570057
# Bias :  -6.5913007646121535
# Weight gradient :  -21.307165147259234
# Bias gradient :  -2.663395643407404
# Weight :  1.6156548824374546
# Bias :  -6.588634702907041
# Weight gradient :  -30.85788413388567
# Bias gradient :  -3.085788413388567
# Weight :  1.6499757412227796
# Bias :  -6.585545825616362
# Weight gradient :  -11.086029481679034
# Bias gradient :  -0.7918592486913596
# Weight :  1.6637781375017437
# Bias :  -6.58475317371577
# Weight gradient :  65.19480610423804
# Bias gradient :  3.6219336724576685
# Weight :  1.5672395780780626
# Bias :  -6.588378732947459
# Mean loss :  4.663511405172676
#
# Epoch number:   22
# Weight gradient :  -24.181494573473277
# Bias gradient :  -4.0302490955788794
# Weight :  1.592349225664937
# Bias :  -6.584344449568501
# Weight gradient :  -21.286175740912412
# Bias gradient :  -2.6607719676140515
# Weight :  1.6151136308189291
# Bias :  -6.5816810141654845
# Weight gradient :  -30.844027451431977
# Bias gradient :  -3.0844027451431977
# Weight :  1.649419077878691
# Bias :  -6.578593523930106
# Weight gradient :  -11.095486144184676
# Bias gradient :  -0.7925347245846197
# Weight :  1.6632332479494891
# Bias :  -6.577800195877469
# Weight gradient :  65.16010078933638
# Bias gradient :  3.620005599407577
# Weight :  1.566746079139649
# Bias :  -6.581423825106105
# Mean loss :  4.6568707359716655
#
# Epoch number:   23
# Weight gradient :  -24.158416874477382
# Bias gradient :  -4.026402812412897
# Weight :  1.5918317632412582
# Bias :  -6.577393391860447
# Weight gradient :  -21.26514534127365
# Bias gradient :  -2.6581431676592064
# Weight :  1.6145736775287012
# Bias :  -6.574732587888816
# Weight gradient :  -30.83010135110282
# Bias gradient :  -3.083010135110282
# Weight :  1.6488636356547193
# Bias :  -6.571646491657474
# Weight gradient :  -11.104809823334179
# Bias gradient :  -0.7932007016667271
# Weight :  1.662689413949599
# Bias :  -6.570852496961111
# Weight gradient :  65.12556226485634
# Bias gradient :  3.6180867924920186
# Weight :  1.566253388775229
# Bias :  -6.574474205462104
# Mean loss :  4.65023155919023
#
# Epoch number:   24
# Weight gradient :  -24.135341699136927
# Bias gradient :  -4.022556949856154
# Weight :  1.5913151120120934
# Bias :  -6.5704476219287145
# Weight gradient :  -21.244105951706736
# Bias gradient :  -2.655513243963342
# Weight :  1.6140345258187492
# Bias :  -6.567789450513335
# Weight gradient :  -30.81615073320167
# Bias gradient :  -3.081615073320167
# Weight :  1.6483089677420075
# Bias :  -6.564704750740242
# Weight gradient :  -11.114071105373952
# Bias gradient :  -0.7938622218124252
# Weight :  1.6621462765749375
# Bias :  -6.563910093861551
# Weight gradient :  65.09111179038331
# Bias gradient :  3.6161728772435175
# Weight :  1.5657612646541657
# Bias :  -6.567529886531465
# Mean loss :  4.6435989969147435
#
# Epoch number:   25
# Weight gradient :  -24.112277521204692
# Bias gradient :  -4.018712920200782
# Weight :  1.5907990384458044
# Bias :  -6.563507150875608
# Weight gradient :  -21.223071630752393
# Bias gradient :  -2.652883953844049
# Weight :  1.6134959571922778
# Bias :  -6.5608516113822715
# Weight gradient :  -30.80219532678033
# Bias gradient :  -3.080219532678033
# Weight :  1.6477548775868727
# Bias :  -6.557768308546758
# Weight gradient :  -11.123301015901163
# Bias gradient :  -0.7945215011357973
# Weight :  1.6616036778995003
# Bias :  -6.556972991728804
# Weight gradient :  65.05671474831914
# Bias gradient :  3.614261930462174
# Weight :  1.5652696001111805
# Bias :  -6.560590871539077
# Mean loss :  4.636975289479845
#
# Epoch number:   26
# Weight gradient :  -24.08922805732488
# Bias gradient :  -4.0148713428874805
# Weight :  1.5902834397364125
# Bias :  -6.556571981305956
# Weight gradient :  -21.2020485502269
# Bias gradient :  -2.6502560687783623
# Weight :  1.6129578754437297
# Bias :  -6.5539190723282
# Weight gradient :  -30.788243798157104
# Bias gradient :  -3.0788243798157104
# Weight :  1.6472012786226387
# Bias :  -6.550837166042098
# Weight gradient :  -11.132513193649444
# Bias gradient :  -0.7951795138321032
# Weight :  1.6610615483371909
# Bias :  -6.5500411905527764
# Weight gradient :  65.02235591300234
# Bias gradient :  3.612353106277908
# Weight :  1.564778348105891
# Bias :  -6.55365715962813
# Mean loss :  4.630361411543717
#
# Epoch number:   27
# Weight gradient :  -24.066194933403644
# Bias gradient :  -4.011032488900607
# Weight :  1.5897682705318477
# Bias :  -6.549642112091693
# Weight gradient :  -21.18103941574539
# Bias gradient :  -2.6476299269681736
# Weight :  1.612420238114543
# Bias :  -6.546991831884517
# Weight gradient :  -30.774299951595143
# Bias gradient :  -3.0774299951595143
# Weight :  1.6466481326219338
# Bias :  -6.543911321378852
# Weight gradient :  -11.141713635843175
# Bias gradient :  -0.7958366882745125
# Weight :  1.6605198571273387
# Bias :  -6.543114688057256
# Weight gradient :  64.98802858151441
# Bias gradient :  3.6104460323063563
# Weight :  1.5642874878031117
# Bias :  -6.546728748149654
# Mean loss :  4.6237577818901645
#
# Epoch number:   28
# Weight gradient :  -24.043178856475834
# Bias gradient :  -4.007196476079305
# Weight :  1.5892535107310977
# Bias :  -6.542717540465891
# Weight gradient :  -21.160045409536743
# Bias gradient :  -2.645005676192093
# Weight :  1.6118830263680346
# Bias :  -6.54006988713637
# Weight gradient :  -30.760365454493126
# Bias gradient :  -3.0760365454493126
# Weight :  1.6460954226025948
# Bias :  -6.536990771475259
# Weight gradient :  -11.150904981269868
# Bias gradient :  -0.7964932129478477
# Weight :  1.65997859057314
# Bias :  -6.536193480971808
# Weight gradient :  64.95372979668119
# Bias gradient :  3.608540544260066
# Weight :  1.5637970098849352
# Bias :  -6.539805633668765
# Mean loss :  4.617164575177126
#
# Epoch number:   29
# Weight gradient :  -24.02018012973926
# Bias gradient :  -4.0033633549565435
# Weight :  1.58873915133109
# Bias :  -6.535798262943083
# Weight gradient :  -21.13906704430861
# Bias gradient :  -2.6423833805385764
# Weight :  1.611346231749445
# Bias :  -6.533153234534136
# Weight gradient :  -30.746441035103818
# Bias gradient :  -3.0746441035103818
# Weight :  1.6455431409198418
# Bias :  -6.5300755127088
# Weight gradient :  -11.160088392685537
# Bias gradient :  -0.7971491709061098
# Weight :  1.659437742477476
# Bias :  -6.5292775655907755
# Weight gradient :  64.9194582475879
# Bias gradient :  3.6066365693104387
# Weight :  1.5633069100954078
# Bias :  -6.532887812406902
# Mean loss :  4.610581858857022
#
# Epoch number:   30
# Weight gradient :  -23.997198878911483
# Bias gradient :  -3.9995331464852475
# Weight :  1.5882251882064145
# Bias :  -6.528884275723734
# Weight gradient :  -21.118104538519965
# Bias gradient :  -2.6397630673149957
# Weight :  1.6108098503669939
# Bias :  -6.526241870250947
# Weight gradient :  -30.732527008929846
# Bias gradient :  -3.0732527008929846
# Weight :  1.644991284032804
# Bias :  -6.523165541221024
# Weight gradient :  -11.169264384129491
# Bias gradient :  -0.7978045988663922
# Weight :  1.6588973099394688
# Bias :  -6.522366938018956
# Weight gradient :  64.88521334685717
# Bias gradient :  3.604734074825398
# Weight :  1.5628171864034222
# Bias :  -6.525975280436199
# Mean loss :  4.604009653312017
#
# Epoch number:   31
# Weight gradient :  -23.974235151713508
# Bias gradient :  -3.9957058586189182
# Weight :  1.587711619375516
# Bias :  -6.521975574872015
# Weight gradient :  -21.097157981313167
# Bias gradient :  -2.637144747664146
# Weight :  1.6102738803344592
# Bias :  -6.519335790339819
# Weight gradient :  -30.718623510074075
# Bias gradient :  -3.0718623510074075
# Weight :  1.6444398502044115
# Bias :  -6.516260853051524
# Weight gradient :  -11.178433184528643
# Bias gradient :  -0.7984595131806174
# Weight :  1.6583572915070681
# Bias :  -6.515461594279571
# Weight gradient :  64.85099482511438
# Bias gradient :  3.602833045839688
# Weight :  1.5623278377558103
# Bias :  -6.519068033764896
# Mean loss :  4.5974479582654
#
# Epoch number:   32
# Weight gradient :  -23.951288961592702
# Bias gradient :  -3.9918814935987834
# Weight :  1.5871984437991904
# Bias :  -6.515072156393926
# Weight gradient :  -21.07622740500129
# Bias gradient :  -2.6345284256251613
# Weight :  1.6097383206471936
# Bias :  -6.51243499080271
# Weight gradient :  -30.704730592917997
# Bias gradient :  -3.0704730592917997
# Weight :  1.6438888384905013
# Bias :  -6.509361444196812
# Weight gradient :  -11.187594897500958
# Bias gradient :  -0.7991139212500684
# Weight :  1.6578176863651184
# Bias :  -6.508561530361726
# Weight gradient :  64.8168025527552
# Bias gradient :  3.6009334751530666
# Weight :  1.561838863529331
# Bias :  -6.512166068374893
# Mean loss :  4.590896764381379
#
# Epoch number:   33
# Weight gradient :  -23.928360306938917
# Bias gradient :  -3.988060051156486
# Weight :  1.5866856608525244
# Bias :  -6.508174016271633
# Weight gradient :  -21.055312816926246
# Bias gradient :  -2.631914102115781
# Weight :  1.6092031706881358
# Bias :  -6.505539467620867
# Weight gradient :  -30.69084827680893
# Bias gradient :  -3.069084827680893
# Weight :  1.643338248295531
# Bias :  -6.502467310636201
# Weight gradient :  -11.196749571589024
# Bias gradient :  -0.7997678265420731
# Weight :  1.6572784939785137
# Bias :  -6.501666742241264
# Weight gradient :  64.7826364616127
# Bias gradient :  3.599035358978483
# Weight :  1.561350263289818
# Bias :  -6.505269380238239
# Mean loss :  4.584356058359646
#
# Epoch number:   34
# Weight gradient :  -23.905449179530052
# Bias gradient :  -3.9842415299216754
# Weight :  1.586173270092814
# Bias :  -6.501281150478558
# Weight gradient :  -21.034414213460373
# Bias gradient :  -2.6293017766825466
# Weight :  1.6086684300107024
# Bias :  -6.4986492167681655
# Weight gradient :  -30.67697656570033
# Bias gradient :  -3.067697656570033
# Weight :  1.6427880791773137
# Bias :  -6.495578448343171
# Weight gradient :  -11.205897231127452
# Bias gradient :  -0.800421230794818
# Weight :  1.6567397139353646
# Bias :  -6.494777225889923
# Weight gradient :  64.74849651053036
# Bias gradient :  3.5971386950294644
# Weight :  1.560862036686325
# Bias :  -6.498377965324387
# Mean loss :  4.577825825172925
#
# Epoch number:   35
# Weight gradient :  -23.882555568243756
# Bias gradient :  -3.980425928040626
# Weight :  1.5856612711575637
# Bias :  -6.494393554986008
# Weight gradient :  -21.013531586160227
# Bias gradient :  -2.6266914482700283
# Weight :  1.6081340982433676
# Bias :  -6.491764234216969
# Weight gradient :  -30.6631154567836
# Bias gradient :  -3.06631154567836
# Weight :  1.6422383307612005
# Bias :  -6.488694853290364
# Weight gradient :  -11.215037889809409
# Bias gradient :  -0.8010741349863864
# Weight :  1.6562013458780702
# Bias :  -6.487892977279367
# Weight gradient :  64.71438267023106
# Bias gradient :  3.5952434816795034
# Weight :  1.560374183404604
# Bias :  -6.491491819603371
# Mean loss :  4.571306049049653
#
# Epoch number:   36
# Weight gradient :  -23.859679460688803
# Bias gradient :  -3.976613243448134
# Weight :  1.5851496637196585
# Bias :  -6.487511225766085
# Weight gradient :  -20.992664924470944
# Bias gradient :  -2.624083115558868
# Weight :  1.6076001750477291
# Bias :  -6.484884515940701
# Weight gradient :  -30.649264944281498
# Bias gradient :  -3.06492649442815
# Weight :  1.6416890027023632
# Bias :  -6.481816521451784
# Weight gradient :  -11.224171556648464
# Bias gradient :  -0.8017265397606046
# Weight :  1.655663389473025
# Bias :  -6.481013992382954
# Weight gradient :  64.6802949166674
# Bias gradient :  3.593349717592634
# Weight :  1.5598867031466581
# Bias :  -6.4846109390472115
# Mean loss :  4.564796713905542
#
# Epoch number:   37
# Weight gradient :  -23.836820843922
# Bias gradient :  -3.9728034739869997
# Weight :  1.5846384474676616
# Bias :  -6.48063415879297
# Weight gradient :  -20.97181421691503
# Bias gradient :  -2.6214767771143785
# Weight :  1.607066660100075
# Bias :  -6.478010057914978
# Weight gradient :  -30.635425021115825
# Bias gradient :  -3.0635425021115825
# Weight :  1.6411400946692172
# Bias :  -6.474943448803755
# Weight gradient :  -11.23329823859978
# Bias gradient :  -0.80237844561427
# Weight :  1.6551258443973031
# Bias :  -6.474140267176513
# Weight gradient :  64.6462332280988
# Bias gradient :  3.591457401561044
# Weight :  1.5593995956217541
# Bias :  -6.477735319630528
# Mean loss :  4.558297803533124
#
# Epoch number:   38
# Weight gradient :  -23.813979704763337
# Bias gradient :  -3.968996617460556
# Weight :  1.584127622097154
# Bias :  -6.473762350043481
# Weight gradient :  -20.95097945161465
# Bias gradient :  -2.6188724314518312
# Weight :  1.606533553083284
# Bias :  -6.471140856118104
# Weight gradient :  -30.621595679639793
# Bias gradient :  -3.0621595679639793
# Weight :  1.6405916063361368
# Bias :  -6.4680756313253465
# Weight gradient :  -11.242417941710997
# Bias gradient :  -0.8030298529793569
# Weight :  1.6545887103328087
# Bias :  -6.467271797638681
# Weight gradient :  64.6121975838073
# Bias gradient :  3.5895665324337394
# Weight :  1.558912860542475
# Bias :  -6.470864957330806
# Mean loss :  4.551809301684953
#
# Epoch number:   39
# Weight gradient :  -23.791156029934402
# Bias gradient :  -3.9651926716557337
# Weight :  1.5836171873069307
# Bias :  -6.466895795497317
# Weight gradient :  -20.930160616521277
# Bias gradient :  -2.6162700770651597
# Weight :  1.6060008536832657
# Bias :  -6.4642769065312855
# Weight gradient :  -30.60777691196037
# Bias gradient :  -3.060777691196037
# Weight :  1.640043537380252
# Bias :  -6.461213064998557
# Weight gradient :  -11.25153067162902
# Bias gradient :  -0.8036807622592157
# Weight :  1.6540519869637025
# Bias :  -6.46040857975105
# Weight gradient :  64.57818796353288
# Bias gradient :  3.58767710908516
# Weight :  1.5584264976229818
# Bias :  -6.463999848128513
# Mean loss :  4.545331192110142
#
# Epoch number:   40
# Weight gradient :  -23.76834980611929
# Bias gradient :  -3.961391634353215
# Weight :  1.5831071427973256
# Bias :  -6.460034491137168
# Weight gradient :  -20.90935769951662
# Bias gradient :  -2.6136697124395774
# Weight :  1.605468561587394
# Bias :  -6.45741820513873
# Weight gradient :  -30.59396871007973
# Bias gradient :  -3.059396871007973
# Weight :  1.639495887480042
# Bias :  -6.4543557458083916
# Weight gradient :  -11.260636433822143
# Bias gradient :  -0.8043311738444388
# Weight :  1.6535156739752712
# Bias :  -6.453550609498237
# Weight gradient :  64.5442043472249
# Bias gradient :  3.585789130401384
# Weight :  1.5579405065782517
# Bias :  -6.457139988007147
# Mean loss :  4.5388634585703675
#
# Epoch number:   41
# Weight gradient :  -23.74556101999135
# Bias gradient :  -3.957593503331892
# Weight :  1.5825974882694775
# Bias :  -6.453178432948756
# Weight gradient :  -20.888570688456873
# Bias gradient :  -2.611071336057109
# Weight :  1.604936676483821
# Bias :  -6.450564747927678
# Weight gradient :  -30.58017106595738
# Bias gradient :  -3.058017106595738
# Weight :  1.6389486563147158
# Bias :  -6.447503669742898
# Weight gradient :  -11.269735233677935
# Bias gradient :  -0.8049810881198525
# Weight :  1.652979771053432
# Bias :  -6.446697882867903
# Weight gradient :  64.51024671493387
# Bias gradient :  3.583902595274104
# Weight :  1.5574548871237424
# Bias :  -6.450285372953262
# Mean loss :  4.53240608484691
#
# Epoch number:   42
# Weight gradient :  -23.722789658224897
# Bias gradient :  -3.953798276370816
# Weight :  1.582088223425007
# Bias :  -6.4463276169208585
# Weight gradient :  -20.867799571192307
# Bias gradient :  -2.6084749463990384
# Weight :  1.6044051980611735
# Bias :  -6.443716530888427
# Weight gradient :  -30.566383971537725
# Bias gradient :  -3.0566383971537725
# Weight :  1.6384018435639405
# Bias :  -6.440656832793178
# Weight gradient :  -11.278827076546314
# Bias gradient :  -0.8056305054675938
# Weight :  1.6524442778845125
# Bias :  -6.439850395850768
# Weight gradient :  64.4763150467627
# Bias gradient :  3.582017502597928
# Weight :  1.5569696389752443
# Bias :  -6.443435998956471
# Mean loss :  4.525959054743696
#
# Epoch number:   43
# Weight gradient :  -23.700035707500383
# Bias gradient :  -3.9500059512500636
# Weight :  1.5815793479658744
# Bias :  -6.43948203904531
# Weight gradient :  -20.847044335575724
# Bias gradient :  -2.6058805419469655
# Weight :  1.6038741260084208
# Bias :  -6.436873550014332
# Weight gradient :  -30.552607418761752
# Bias gradient :  -3.0552607418761752
# Weight :  1.6378554489077222
# Bias :  -6.433815230953395
# Weight gradient :  -11.28791196775795
# Bias gradient :  -0.806279426268425
# Weight :  1.6519091941551562
# Bias :  -6.433008144440614
# Weight gradient :  64.44240932284642
# Bias gradient :  3.5801338512692453
# Weight :  1.5564847618488167
# Bias :  -6.436591862009452
# Mean loss :  4.519522352088618
#
# Epoch number:   44
# Weight gradient :  -23.677299154506677
# Bias gradient :  -3.9462165257511126
# Weight :  1.581070861594316
# Bias :  -6.432641695317009
# Weight gradient :  -20.826304969466257
# Bias gradient :  -2.603288121183282
# Weight :  1.603343460014816
# Bias :  -6.43003580130181
# Weight gradient :  -30.53884139957244
# Bias gradient :  -3.053884139957244
# Weight :  1.6373094720263526
# Bias :  -6.426978860220772
# Weight gradient :  -11.296989912633414
# Bias gradient :  -0.8069278509023867
# Weight :  1.6513745195522782
# Bias :  -6.426171124634283
# Weight gradient :  64.40852952334237
# Bias gradient :  3.5782516401856874
# Weight :  1.5560002554607573
# Bias :  -6.429752958107943
# Mean loss :  4.513095960734107
#
# Epoch number:   45
# Weight gradient :  -23.65457998594204
# Bias gradient :  -3.9424299976570065
# Weight :  1.5805627640128177
# Bias :  -6.425806581733912
# Weight gradient :  -20.805581460731105
# Bias gradient :  -2.600697682591388
# Weight :  1.6028131997698687
# Bias :  -6.423203280750338
# Weight gradient :  -30.525085905917386
# Bias gradient :  -3.0525085905917386
# Weight :  1.6367639126003852
# Bias :  -6.420147716595591
# Weight gradient :  -11.306060916486118
# Bias gradient :  -0.8075757797490084
# Weight :  1.650840253763048
# Bias :  -6.419339332431678
# Weight gradient :  64.37467562842599
# Bias gradient :  3.5763708682458883
# Weight :  1.5555161195275906
# Bias :  -6.422919283250742
# Mean loss :  4.506679864557347
#
# Epoch number:   46
# Weight gradient :  -23.631878188514555
# Bias gradient :  -3.938646364752426
# Weight :  1.5800550549241017
# Bias :  -6.4189766942970365
# Weight gradient :  -20.784873797246092
# Bias gradient :  -2.5981092246557616
# Weight :  1.6022833449633356
# Bias :  -6.416375984362446
# Weight gradient :  -30.51134092974925
# Bias gradient :  -3.051134092974925
# Weight :  1.6362187703106266
# Bias :  -6.41332179608119
# Weight gradient :  -11.315124984624049
# Bias gradient :  -0.8082232131874321
# Weight :  1.6503063964748803
# Bias :  -6.412512763835757
# Weight gradient :  64.3408476182895
# Bias gradient :  3.5744915343494164
# Weight :  1.5550323537660626
# Bias :  -6.416090833439711
# Mean loss :  4.500274047460343
#
# Epoch number:   47
# Weight gradient :  -23.60919374894234
# Bias gradient :  -3.934865624823723
# Weight :  1.5795477340311226
# Bias :  -6.412152029010458
# Weight gradient :  -20.76418196689611
# Bias gradient :  -2.595522745862014
# Weight :  1.6017538952852144
# Bias :  -6.409553908143729
# Weight gradient :  -30.497606463026656
# Bias gradient :  -3.0497606463026656
# Weight :  1.6356740448381302
# Bias :  -6.406501094683967
# Weight gradient :  -11.32418212235082
# Bias gradient :  -0.8088701515964871
# Weight :  1.6497729473754321
# Bias :  -6.405691414852539
# Weight gradient :  64.3070454731409
# Bias gradient :  3.5726136373967172
# Weight :  1.5545489578931377
# Bias :  -6.409267604679763
# Mean loss :  4.493878493369965
#
# Epoch number:   48
# Weight gradient :  -23.586526653953552
# Bias gradient :  -3.9310877756589253
# Weight :  1.5790408010370633
# Bias :  -6.405332581881305
# Weight gradient :  -20.743505957575167
# Bias gradient :  -2.592938244696896
# Weight :  1.6012248504257418
# Bias :  -6.40273704810283
# Weight gradient :  -30.483882497714117
# Bias gradient :  -3.0483882497714117
# Weight :  1.6351297358641959
# Bias :  -6.399685608413369
# Weight gradient :  -11.333232334965615
# Bias gradient :  -0.8095165953546868
# Weight :  1.6492399061526006
# Bias :  -6.398875281491092
# Weight gradient :  64.2732691732036
# Bias gradient :  3.5707371762890894
# Weight :  1.5540659316259977
# Bias :  -6.4024495929788685
# Mean loss :  4.48749318623789
#
# Epoch number:   49
# Weight gradient :  -23.563876890286515
# Bias gradient :  -3.9273128150477525
# Weight :  1.578534255645335
# Bias :  -6.398518348919762
# Weight gradient :  -20.722845757186498
# Bias gradient :  -2.5903557196483122
# Weight :  1.6006962100753916
# Bias :  -6.395925400251445
# Weight gradient :  -30.470169025782248
# Bias gradient :  -3.0470169025782248
# Weight :  1.634585843070367
# Bias :  -6.392875333281897
# Weight gradient :  -11.342275627763293
# Bias gradient :  -0.8101625448402352
# Weight :  1.6487072724945215
# Bias :  -6.3920643597635385
# Weight gradient :  64.23951869871605
# Bias gradient :  3.5688621499286697
# Weight :  1.5535832746820402
# Bias :  -6.395636794348052
# Mean loss :  4.481118110040592
#
# Epoch number:   50
# Weight gradient :  -23.541244444689667
# Bias gradient :  -3.923540740781611
# Weight :  1.578028097559575
# Bias :  -6.391709326139061
# Weight gradient :  -20.70220135364258
# Bias gradient :  -2.5877751692053224
# Weight :  1.6001679739248749
# Bias :  -6.389118960604321
# Weight gradient :  -30.45646603920794
# Bias gradient :  -3.045646603920794
# Weight :  1.6340423661384307
# Bias :  -6.386070265305102
# Weight gradient :  -11.35131200603503
# Bias gradient :  -0.8108080004310736
# Weight :  1.6481750460895697
# Bias :  -6.385258645685051
# Weight gradient :  64.20579402993212
# Bias gradient :  3.566988557218451
# Weight :  1.5531009867788799
# Bias :  -6.388829204801385
# Mean loss :  4.474753248779342
#
# Epoch number:   51
# Weight gradient :  -23.518629303921568
# Bias gradient :  -3.9197715506535946
# Weight :  1.5775223264836484
# Bias :  -6.384905509555486
# Weight gradient :  -20.68157273486512
# Bias gradient :  -2.58519659185814
# Weight :  1.599640141665139
# Bias :  -6.382317725179251
# Weight gradient :  -30.442773529973977
# Bias gradient :  -3.0442773529973977
# Weight :  1.6334993047504176
# Bias :  -6.379270400501576
# Weight gradient :  -11.360341475067628
# Bias gradient :  -0.8114529625048306
# Weight :  1.6476432266263579
# Bias :  -6.378458135273843
# Weight gradient :  64.17209514712059
# Bias gradient :  3.565116397062255
# Weight :  1.552619067634347
# Bias :  -6.382026820355987
# Mean loss :  4.4683985864801095
#
# Epoch number:   52
# Weight gradient :  -23.496031454750902
# Bias gradient :  -3.9160052424584837
# Weight :  1.5770169421216464
# Bias :  -6.3781068951883615
# Weight gradient :  -20.66095988878503
# Bias gradient :  -2.5826199860981287
# Weight :  1.599112712987368
# Bias :  -6.375521689997072
# Weight gradient :  -30.429091490069453
# Bias gradient :  -3.0429091490069453
# Weight :  1.6329566585886017
# Bias :  -6.372475734892961
# Weight gradient :  -11.369364040144006
# Bias gradient :  -0.8120974314388576
# Weight :  1.6471118137937373
# Bias :  -6.371662824551181
# Weight gradient :  64.13842203056551
# Bias gradient :  3.5632456683647504
# Weight :  1.5521375169664877
# Bias :  -6.375229637032026
# Mean loss :  4.462054107193574
#
# Epoch number:   53
# Weight gradient :  -23.47345088395646
# Bias gradient :  -3.9122418139927433
# Weight :  1.5765119441778863
# Bias :  -6.371313479060062
# Weight gradient :  -20.640362803342477
# Bias gradient :  -2.5800453504178096
# Weight :  1.598585687582982
# Bias :  -6.368730851081666
# Weight gradient :  -30.415419911489323
# Bias gradient :  -3.0415419911489323
# Weight :  1.6324144273355006
# Bias :  -6.365686264503939
# Weight gradient :  -11.37837970654276
# Bias gradient :  -0.8127414076101971
# Weight :  1.6465808072807977
# Bias :  -6.364872709541366
# Weight gradient :  64.10477466056597
# Bias gradient :  3.561376370031443
# Weight :  1.5516563344935639
# Bias :  -6.368437650852709
# Mean loss :  4.455719794995054
#
# Epoch number:   54
# Weight gradient :  -23.450887578327162
# Bias gradient :  -3.9084812630545267
# Weight :  1.576007332356912
# Bias :  -6.364525257195997
# Weight gradient :  -20.619781466486806
# Bias gradient :  -2.5774726833108508
# Weight :  1.5980590651436375
# Bias :  -6.361945204459951
# Weight gradient :  -30.40175878623497
# Bias gradient :  -3.040175878623497
# Weight :  1.6318726106738732
# Bias :  -6.3589019853622295
# Weight gradient :  -11.38738847953875
# Bias gradient :  -0.813384891395625
# Weight :  1.6460502067768654
# Bias :  -6.358087786271743
# Weight gradient :  64.07115301743585
# Bias gradient :  3.559508500968658
# Weight :  1.5511755199340524
# Bias :  -6.3616508578442845
# Mean loss :  4.449395633984491
#
# Epoch number:   55
# Weight gradient :  -23.428341524662006
# Bias gradient :  -3.9047235874436677
# Weight :  1.5755031063634923
# Bias :  -6.357742225624621
# Weight gradient :  -20.599215866176635
# Bias gradient :  -2.5749019832720794
# Weight :  1.5975328453612259
# Bias :  -6.355164746161886
# Weight gradient :  -30.388108106313716
# Bias gradient :  -3.0388108106313716
# Weight :  1.6313312082867222
# Bias :  -6.352122893498592
# Weight gradient :  -11.396390364402762
# Bias gradient :  -0.8140278831716259
# Weight :  1.645520011971505
# Bias :  -6.351308050772695
# Weight gradient :  64.03755708150445
# Bias gradient :  3.5576420600835803
# Weight :  1.5506950730066458
# Bias :  -6.354869254036042
# Mean loss :  4.443081608286414
#
# Epoch number:   56
# Weight gradient :  -23.405812709770103
# Bias gradient :  -3.900968784961684
# Weight :  1.5749992659026228
# Bias :  -6.350964380377421
# Weight gradient :  -20.578665990379783
# Bias gradient :  -2.572333248797473
# Weight :  1.5970070279278743
# Bias :  -6.348389472220467
# Weight gradient :  -30.374467863739056
# Bias gradient :  -3.0374467863739056
# Weight :  1.6307902198572914
# Bias :  -6.34534898494682
# Weight gradient :  -11.405385366401404
# Bias gradient :  -0.814670383314386
# Weight :  1.6449902225545179
# Bias :  -6.344533499077636
# Weight gradient :  64.00398683311602
# Bias gradient :  3.5557770462842235
# Weight :  1.5502149934302514
# Bias :  -6.348092835460303
# Mean loss :  4.436777702049893
#
# Epoch number:   57
# Weight gradient :  -23.38330112047065
# Bias gradient :  -3.8972168534117753
# Weight :  1.5744958106795242
# Bias :  -6.34419171748892
# Weight gradient :  -20.558131827073204
# Bias gradient :  -2.5697664783841505
# Weight :  1.596481612535946
# Bias :  -6.3416193786717185
# Weight gradient :  -30.360838050530514
# Bias gradient :  -3.0360838050530514
# Weight :  1.6302496450690687
# Bias :  -6.338580255743738
# Weight gradient :  -11.414373490797303
# Bias gradient :  -0.8153123921998073
# Weight :  1.6444608382159436
# Bias :  -6.337764127223017
# Weight gradient :  63.97044225262977
# Bias gradient :  3.553913458479432
# Weight :  1.5497352809239922
# Bias :  -6.341321598152426
# Mean loss :  4.430483899448488
#
# Epoch number:   58
# Weight gradient :  -23.360806743592875
# Bias gradient :  -3.8934677905988124
# Weight :  1.573992740399643
# Bias :  -6.337424232996671
# Weight gradient :  -20.53761336424307
# Bias gradient :  -2.567201670530384
# Weight :  1.5959565988780393
# Bias :  -6.3348544615546984
# Weight gradient :  -30.347218658713793
# Bias gradient :  -3.0347218658713793
# Weight :  1.6297094836057824
# Bias :  -6.331816701929202
# Weight gradient :  -11.423354742849106
# Bias gradient :  -0.8159539102035076
# Weight :  1.6439318586460578
# Bias :  -6.330999931248317
# Weight gradient :  63.936923320419986
# Bias gradient :  3.552051295578888
# Weight :  1.5492559352072048
# Bias :  -6.3345555381507985
# Mean loss :  4.424200184680231
#
# Epoch number:   59
# Weight gradient :  -23.338329565976146
# Bias gradient :  -3.889721594329358
# Weight :  1.5734900547686503
# Bias :  -6.3306619229412595
# Weight gradient :  -20.517110589884794
# Bias gradient :  -2.5646388237355993
# Weight :  1.5954319866469868
# Bias :  -6.328094716911494
# Weight gradient :  -30.333609680320652
# Bias gradient :  -3.0333609680320652
# Weight :  1.6291697351514032
# Bias :  -6.3250583195460965
# Weight gradient :  -11.432329127811435
# Bias gradient :  -0.8165949377008168
# Weight :  1.6434032835353736
# Bias :  -6.324240907196046
# Weight gradient :  63.903430016875916
# Bias gradient :  3.5501905564931064
# Weight :  1.5487769559994413
# Bias :  -6.3277946514968395
# Mean loss :  4.41792654196759
#
# Epoch number:   60
# Weight gradient :  -23.315869574469854
# Bias gradient :  -3.8859782624116423
# Weight :  1.5729877534924426
# Bias :  -6.323904783366297
# Weight gradient :  -20.49662349200291
# Bias gradient :  -2.562077936500364
# Weight :  1.5949077755358567
# Bias :  -6.321340140787218
# Weight gradient :  -30.320011107389
# Bias gradient :  -3.0320011107389
# Weight :  1.6286303993901432
# Bias :  -6.318305104640332
# Weight gradient :  -11.44129665093493
# Bias gradient :  -0.8172354750667807
# Weight :  1.6428751125746397
# Bias :  -6.317487051111736
# Weight gradient :  63.86996232240172
# Bias gradient :  3.548331240133429
# Weight :  1.5482983430204678
# Bias :  -6.321038934234993
# Mean loss :  4.411662955557416
#
# Epoch number:   61
# Weight gradient :  -23.293426755933453
# Bias gradient :  -3.882237792655576
# Weight :  1.5724858362771408
# Bias :  -6.317152810318421
# Weight gradient :  -20.476152058611177
# Bias gradient :  -2.559519007326397
# Weight :  1.5943839652379512
# Bias :  -6.314590729230007
# Weight gradient :  -30.3064229319628
# Bias gradient :  -3.03064229319628
# Weight :  1.6280914760064562
# Bias :  -6.311557053260842
# Weight gradient :  -11.450257317466153
# Bias gradient :  -0.8178755226761538
# Weight :  1.6423473454548425
# Bias :  -6.310738359043949
# Weight gradient :  63.83652021741658
# Bias gradient :  3.546473345412032
# Weight :  1.5478200959902646
# Bias :  -6.314288382412729
# Mean loss :  4.4054094097209155
#
# Epoch number:   62
# Weight gradient :  -23.271001097236457
# Bias gradient :  -3.8785001828727426
# Weight :  1.5719843028290914
# Bias :  -6.3104059998472914
# Weight gradient :  -20.455696277732443
# Bias gradient :  -2.5569620347165554
# Weight :  1.593860555446808
# Bias :  -6.307846478291019
# Weight gradient :  -30.292845146092056
# Bias gradient :  -3.0292845146092056
# Weight :  1.6275529646850373
# Bias :  -6.3048141614595785
# Weight gradient :  -11.459211132647638
# Bias gradient :  -0.8185150809034027
# Weight :  1.6418199818672041
# Bias :  -6.30399482704426
# Weight gradient :  63.803103682354894
# Bias gradient :  3.5446168712419386
# Weight :  1.5473422146290265
# Bias :  -6.307542992080538
# Mean loss :  4.399165888753615
#
# Epoch number:   63
# Weight gradient :  -23.248592585258393
# Bias gradient :  -3.8747654308763986
# Weight :  1.5714831528548647
# Bias :  -6.303664348005587
# Weight gradient :  -20.43525613739878
# Bias gradient :  -2.5544070171748476
# Weight :  1.593337545856198
# Bias :  -6.301107384024432
# Weight gradient :  -30.2792777418329
# Bias gradient :  -3.02792777418329
# Weight :  1.6270148651108225
# Bias :  -6.298076425291516
# Weight gradient :  -11.46815810171799
# Bias gradient :  -0.8191541501227135
# Weight :  1.6412930215031825
# Bias :  -6.297256451167269
# Weight gradient :  63.76971269766578
# Bias gradient :  3.542761816536988
# Weight :  1.5468646986571621
# Bias :  -6.300802759291931
# Mean loss :  4.392932376975316
#
# Epoch number:   64
# Weight gradient :  -23.226201206888824
# Bias gradient :  -3.8710335344814704
# Weight :  1.570982386061256
# Bias :  -6.2969278508490065
# Weight gradient :  -20.414831625651345
# Bias gradient :  -2.551853953206418
# Weight :  1.5928149361601276
# Bias :  -6.294373442487439
# Weight gradient :  -30.265720711247468
# Bias gradient :  -3.026572071124747
# Weight :  1.6264771769689892
# Bias :  -6.291343840814641
# Weight gradient :  -11.477098229911682
# Bias gradient :  -0.8197927307079773
# Weight :  1.6407664640544724
# Bias :  -6.290523227470589
# Weight gradient :  63.73634724381344
# Bias gradient :  3.540908180211858
# Weight :  1.546387547795294
# Bias :  -6.294067680103434
# Mean loss :  4.386708858730056
#
# Epoch number:   65
# Weight gradient :  -23.20382694902736
# Bias gradient :  -3.8673044915045596
# Weight :  1.5704820021552839
# Bias :  -6.290196504436262
# Weight gradient :  -20.39442273054049
# Bias gradient :  -2.5493028413175614
# Weight :  1.592292726052836
# Bias :  -6.2876446497402485
# Weight gradient :  -30.252174046404097
# Bias gradient :  -3.0252174046404097
# Weight :  1.6259398999449548
# Bias :  -6.284616404089958
# Weight gradient :  -11.486031522459264
# Bias gradient :  -0.8204308230328046
# Weight :  1.6402403092130031
# Bias :  -6.28379515201485
# Weight gradient :  63.703007301276784
# Bias gradient :  3.5390559611820436
# Weight :  1.5459107617642573
# Bias :  -6.287337750574592
# Mean loss :  4.3804953183860835
#
# Epoch number:   66
# Weight gradient :  -23.1814697985836
# Bias gradient :  -3.863578299763933
# Weight :  1.5699820008441916
# Bias :  -6.283470304829082
# Weight gradient :  -20.374029440125724
# Bias gradient :  -2.5467536800157156
# Weight :  1.591770915228796
# Bias :  -6.2809210018460835
# Weight gradient :  -30.23863773937709
# Bias gradient :  -3.023863773937709
# Weight :  1.6254030337243772
# Bias :  -6.277894111181481
# Weight gradient :  -11.4949579845875
# Bias gradient :  -0.8210684274705358
# Weight :  1.63971455667094
# Bias :  -6.277072220863692
# Weight gradient :  63.66969285054969
# Bias gradient :  3.5372051583638715
# Weight :  1.5454343402851018
# Bias :  -6.28061296676796
# Mean loss :  4.374291740335808
#
# Epoch number:   67
# Weight gradient :  -23.159129742477173
# Bias gradient :  -3.859854957079529
# Weight :  1.569482381835446
# Bias :  -6.276749248092205
# Weight gradient :  -20.35365174247564
# Bias gradient :  -2.544206467809455
# Weight :  1.591249503382715
# Bias :  -6.274202494871175
# Weight gradient :  -30.225111782246827
# Bias gradient :  -3.0225111782246827
# Weight :  1.6248665779931553
# Bias :  -6.271176958156236
# Weight gradient :  -11.503877621518683
# Bias gradient :  -0.8217055443941916
# Weight :  1.639189206120684
# Bias :  -6.270354430083769
# Weight gradient :  63.63640387214137
# Bias gradient :  3.5353557706745207
# Weight :  1.5449582830790904
# Bias :  -6.273893324749109
# Mean loss :  4.368098108995783
#
# Epoch number:   68
# Weight gradient :  -23.13680676763772
# Bias gradient :  -3.856134461272953
# Weight :  1.5689831448367377
# Bias :  -6.27003333029338
# Weight gradient :  -20.333289625667952
# ...
# Bias gradient :  -2.136112685542283
# Weight :  1.2733102726120673
# Bias :  -1.869215411662957
# Weight gradient :  -17.349196111703883
# Bias gradient :  -1.2392282936931345
# Weight :  1.2949104749433835
# Bias :  -1.8679749429005013
# Weight gradient :  41.82108980602758
# Bias gradient :  2.3233938781126433
# Weight :  1.2329830300339364
# Bias :  -1.8703006624982117
# Mean loss :  1.4278261521172664
#
# Epoch number:   978
# Weight gradient :  -8.507859581634335
# Bias gradient :  -1.4179765969390559
# Weight :  1.241817444927704
# Bias :  -1.8688812665052796
# Weight gradient :  -6.98935435193971
# Bias gradient :  -0.8736692939924637
# Weight :  1.2492921785843731
# Bias :  -1.8680067226674493
# Weight gradient :  -21.354388666982036
# Bias gradient :  -2.1354388666982036
# Weight :  1.2730430279526104
# Bias :  -1.865869146224308
# Weight gradient :  -17.353639582423654
# Bias gradient :  -1.2395456844588324
# Weight :  1.294648762521039
# Bias :  -1.8646283597533782
# Weight gradient :  41.80450632824804
# Bias gradient :  2.3224725737915577
# Weight :  1.2327458739397832
# Bias :  -1.8669531571245408
# Mean loss :  1.4264407178011962
#
# Epoch number:   979
# Weight gradient :  -8.496739007350506
# Bias gradient :  -1.416123167891751
# Weight :  1.2415687414206982
# Bias :  -1.8655356164159405
# Weight gradient :  -6.97921061284741
# Bias gradient :  -0.8724013266059263
# Weight :  1.249032626901101
# Bias :  -1.8646623418147332
# Weight gradient :  -21.34765563057826
# Bias gradient :  -2.134765563057826
# Weight :  1.2727759876291382
# Bias :  -1.8625254393492099
# Weight gradient :  -17.35807965565383
# Bias gradient :  -1.2398628325467023
# Weight :  1.294387250204716
# Bias :  -1.8612843354127266
# Weight gradient :  41.78793553024016
# Bias gradient :  2.3215519739022312
# Weight :  1.232508899175817
# Bias :  -1.8636082112624786
# Mean loss :  1.4250576321581225
#
# Epoch number:   980
# Weight gradient :  -8.485626935887673
# Bias gradient :  -1.4142711559812788
# Weight :  1.2413202280730626
# Bias :  -1.8621925244196544
# Weight gradient :  -6.969074629685267
# Bias gradient :  -0.8711343287106583
# Weight :  1.2487732736717438
# Bias :  -1.8613205180846086
# Weight gradient :  -21.340927742272218
# Bias gradient :  -2.1340927742272218
# Weight :  1.2725091514854157
# Bias :  -1.8591842890813781
# Weight gradient :  -17.362516333992033
# Bias gradient :  -1.240179738142288
# Weight :  1.2941259378414134
# Bias :  -1.8579428679220766
# Weight gradient :  41.77137740230905
# Bias gradient :  2.3206320779060583
# Weight :  1.232272105603393
# Bias :  -1.8602658229550155
# Mean loss :  1.4236768914212896
#
# Epoch number:   981
# Weight gradient :  -8.474523360744547
# Bias gradient :  -1.4124205601240911
# Weight :  1.241071904739401
# Bias :  -1.8588519885604968
# Weight gradient :  -6.958946396523103
# Bias gradient :  -0.8698682995653879
# Weight :  1.2485141187445632
# Bias :  -1.8579812495218928
# Weight gradient :  -21.334204998127664
# Bias gradient :  -2.1334204998127664
# Weight :  1.2722425193653257
# Bias :  -1.8558456934660241
# Weight gradient :  -17.366949620034084
# Bias gradient :  -1.240496401431006
# Weight :  1.2938648252782463
# Bias :  -1.8546039553264535
# Weight gradient :  41.754831934767026
# Bias gradient :  2.3197128852648348
# Weight :  1.2320354930839708
# Bias :  -1.8569259902466386
# Mean loss :  1.4222984918298365
#
# Epoch number:   982
# Weight gradient :  -8.463428275424835
# Bias gradient :  -1.4105713792374726
# Weight :  1.2408237712744277
# Bias :  -1.8555140068840386
# Weight gradient :  -6.94882590743525
# Bias gradient :  -0.8686032384294062
# Weight :  1.2482551619679365
# Bias :  -1.854644534172898
# Weight gradient :  -21.327487394211335
# Bias gradient :  -2.1327487394211335
# Weight :  1.271976091112872
# Bias :  -1.852509650549854
# Weight gradient :  -17.371379516373672
# Bias gradient :  -1.2408128225981194
# Weight :  1.293603912362447
# Bias :  -1.8512675956723783
# Weight gradient :  41.73829911793396
# Bias gradient :  2.3187943954407757
# Weight :  1.231799061479117
# Bias :  -1.85358871118333
# Mean loss :  1.4209224296287857
#
# Epoch number:   983
# Weight gradient :  -8.452341673437193
# Bias gradient :  -1.4087236122395321
# Weight :  1.2405758275329688
# Bias :  -1.8521785774373445
# Weight gradient :  -6.938713156500555
# Bias gradient :  -0.8673391445625693
# Weight :  1.2479964031903577
# Bias :  -1.85131037008543
# Weight gradient :  -21.320774926593042
# Bias gradient :  -2.1320774926593042
# Weight :  1.2717098665721762
# Bias :  -1.8491761583810664
# Weight gradient :  -17.375806025602643
# Bias gradient :  -1.2411290018287602
# Weight :  1.2933431989413646
# Bias :  -1.8479337870078645
# Weight gradient :  41.72177894213715
# Bias gradient :  2.3178766078965083
# Weight :  1.231562810650504
# Bias :  -1.8502539838125658
# Mean loss :  1.4195487010690389
#
# Epoch number:   984
# Weight gradient :  -8.441263548295234
# Bias gradient :  -1.4068772580492057
# Weight :  1.2403280733699613
# Bias :  -1.848845698268973
# Weight gradient :  -6.928608137802428
# Bias gradient :  -0.8660760172253035
# Weight :  1.2477378422604355
# Bias :  -1.8479787553087874
# Weight gradient :  -21.314067591345545
# Bias gradient :  -2.1314067591345545
# Weight :  1.27144384558748
# Bias :  -1.8458452150093534
# Weight gradient :  -17.380229150310754
# Bias gradient :  -1.241444939307911
# Weight :  1.2930826848624648
# Bias :  -1.8446025273824185
# Weight gradient :  41.7052713977111
# Bias gradient :  2.316959522095061
# Weight :  1.2313267404599098
# Bias :  -1.8469218061833144
# Mean loss :  1.4181773024073556
#
# Epoch number:   985
# Weight gradient :  -8.430193893517536
# Bias gradient :  -1.405032315586256
# Weight :  1.240080508640453
# Bias :  -1.8455153674289737
# Weight gradient :  -6.918510845428756
# Bias gradient :  -0.8648138556785945
# Weight :  1.2474794790268957
# Bias :  -1.84464968789376
# Weight gradient :  -21.307365384544603
# Bias gradient :  -2.1307365384544603
# Weight :  1.2711780280031437
# Bias :  -1.8425168184858975
# Weight gradient :  -17.384648893085824
# Bias gradient :  -1.241760635220416
# Weight :  1.29282236997333
# Bias :  -1.8412738148470382
# Weight gradient :  41.68877647499801
# Bias gradient :  2.3160431374998893
# Weight :  1.231090850769218
# Bias :  -1.843592176346037
# Mean loss :  1.4168082299063591
#
# Epoch number:   986
# Weight gradient :  -8.419132702627643
# Bias gradient :  -1.4031887837712738
# Weight :  1.2398331331996024
# Bias :  -1.8421875829688885
# Weight gradient :  -6.908421273471973
# Bias gradient :  -0.8635526591839966
# Weight :  1.247221313338579
# Bias :  -1.8413231658926283
# Weight gradient :  -21.30066830226898
# Bias gradient :  -2.130066830226898
# Weight :  1.2709124136636474
# Bias :  -1.8391909668633721
# Weight gradient :  -17.389065256513632
# Bias gradient :  -1.2420760897509737
# Weight :  1.2925622541216597
# Bias :  -1.837947647454212
# Weight gradient :  41.67229416434709
# Bias gradient :  2.3151274535748385
# Weight :  1.2308551414404179
# Bias :  -1.8402650923526853
# Mean loss :  1.4154414798345107
#
# Epoch number:   987
# Weight gradient :  -8.408079969154052
# Bias gradient :  -1.4013466615256753
# Weight :  1.2395859469026789
# Bias :  -1.8388623429417488
# Weight gradient :  -6.898339416029046
# Bias gradient :  -0.8622924270036307
# Weight :  1.2469633450444415
# Bias :  -1.8379991873591626
# Weight gradient :  -21.293976340600498
# Bias gradient :  -2.12939763406005
# Weight :  1.270647002413589
# Bias :  -1.8358676581959392
# Weight gradient :  -17.393478243178166
# Bias gradient :  -1.2423913030841547
# Weight :  1.2923023371552687
# Bias :  -1.834624023257917
# Weight gradient :  41.65582445611513
# Bias gradient :  2.3142124697841737
# Weight :  1.2306196123356041
# Bias :  -1.8369405522567
# Mean loss :  1.4140770484661214
#
# Epoch number:   988
# Weight gradient :  -8.397035686630188
# Bias gradient :  -1.399505947771698
# Weight :  1.2393389496050626
# Bias :  -1.8355396454020736
# Weight gradient :  -6.888265267201419
# Bias gradient :  -0.8610331584001774
# Weight :  1.2467055739935553
# Bias :  -1.83467775034862
# Weight gradient :  -21.287289495623885
# Bias gradient :  -2.1287289495623885
# Weight :  1.270381794097686
# Bias :  -1.8325468905392484
# Weight gradient :  -17.397887855661224
# Bias gradient :  -1.2427062754043732
# Weight :  1.292042618922089
# Bias :  -1.8313029403136183
# Weight gradient :  41.63936734066649
# Bias gradient :  2.3132981855925827
# Weight :  1.2303842633169773
# Bias :  -1.8336185541130103
# Mean loss :  1.4127149320813277
#
# Epoch number:   989
# Weight gradient :  -8.38599984859443
# Bias gradient :  -1.397666641432405
# Weight :  1.2390921411622442
# Bias :  -1.832219488405871
# Weight gradient :  -6.878198821095083
# Bias gradient :  -0.8597748526368854
# Weight :  1.2464480000351075
# Bias :  -1.8313588529177458
# Weight gradient :  -21.280607763426946
# Bias gradient :  -2.1280607763426946
# Weight :  1.2701167885607743
# Bias :  -1.8292286619504359
# Weight gradient :  -17.402294096542718
# Bias gradient :  -1.2430210068959084
# Weight :  1.2917830992701687
# Bias :  -1.8279843966782678
# Weight gradient :  41.622922808372465
# Bias gradient :  2.312384600465137
# Weight :  1.2301490942468427
# Bias :  -1.8302990959780328
# Mean loss :  1.411355126966082
#
# Epoch number:   990
# Weight gradient :  -8.374972448590114
# Bias gradient :  -1.3958287414316857
# Weight :  1.2388455214298246
# Bias :  -1.8289018700106336
# Weight gradient :  -6.8681400718205055
# Bias gradient :  -0.8585175089775632
# Weight :  1.246190623018401
# Bias :  -1.8280424931247703
# Weight gradient :  -21.273931140100384
# Bias gradient :  -2.1273931140100384
# Weight :  1.2698519856478085
# Bias :  -1.8259129704881236
# Weight gradient :  -17.406696968400567
# Bias gradient :  -1.2433354977428976
# Weight :  1.2915237780476718
# Bias :  -1.824668390410303
# Weight gradient :  41.60649084961214
# Bias gradient :  2.3114717138673413
# Weight :  1.2299141049876117
# Bias :  -1.8269821759096696
# Mean loss :  1.4099976294121537
#
# Epoch number:   991
# Weight gradient :  -8.363953480165488
# Bias gradient :  -1.393992246694248
# Weight :  1.2385990902635156
# Bias :  -1.825586788275341
# Weight gradient :  -6.858089013492659
# Bias gradient :  -0.8572611266865824
# Weight :  1.2459334427928532
# Bias :  -1.8247286690294084
# Weight gradient :  -21.26725962173797
# Bias gradient :  -2.126725962173797
# Weight :  1.269587385203862
# Bias :  -1.8225998142124176
# Weight gradient :  -17.4110964738108
# Bias gradient :  -1.243649748129343
# Weight :  1.2912646551028788
# Bias :  -1.8213549195696455
# Weight gradient :  41.59007145477152
# Bias gradient :  2.3105595252650843
# Weight :  1.2296792954017997
# Bias :  -1.823667791967308
# Mean loss :  1.408642435717108
#
# Epoch number:   992
# Weight gradient :  -8.352942936873736
# Bias gradient :  -1.3921571561456227
# Weight :  1.2383528475191388
# Bias :  -1.8222742412604556
# Weight gradient :  -6.848045640231021
# Bias gradient :  -0.8560057050288776
# Weight :  1.2456764592079976
# Bias :  -1.8214173786928591
# Weight gradient :  -21.26059320443643
# Bias gradient :  -2.126059320443643
# Weight :  1.2693229870741265
# Bias :  -1.8192891911849076
# Weight gradient :  -17.41549261534731
# Bias gradient :  -1.2439637582390937
# Weight :  1.2910057302841864
# Bias :  -1.8180439822177012
# Weight gradient :  41.573664614244514
# Bias gradient :  2.309648034124695
# Weight :  1.2294446653520286
# Bias :  -1.82035594221182
# Mean loss :  1.4072895421843137
#
# Epoch number:   993
# Weight gradient :  -8.341940812272993
# Bias gradient :  -1.3903234687121655
# Weight :  1.2381067930526264
# Bias :  -1.818964227027924
# Weight gradient :  -6.838009946159616
# Bias gradient :  -0.854751243269952
# Weight :  1.2454196721134816
# Bias :  -1.818108620177804
# Weight gradient :  -21.2539318842955
# Bias gradient :  -2.12539318842955
# Weight :  1.2690587911039115
# Bias :  -1.8159810994686654
# Weight gradient :  -17.4198853955822
# Bias gradient :  -1.2442775282558713
# Weight :  1.2907470034401063
# Bias :  -1.8147355764173583
# Weight gradient :  41.55727031843177
# Bias gradient :  2.308737239912876
# Weight :  1.2292102147010242
# Bias :  -1.8170466247055594
# Mean loss :  1.4059389451229152
#
# Epoch number:   994
# Weight gradient :  -8.3309470999263
# Bias gradient :  -1.38849118332105
# Weight :  1.2378609267200207
# Bias :  -1.815656743641174
# Weight gradient :  -6.8279819254068315
# Bias gradient :  -0.8534977406758539
# Weight :  1.2451630813590688
# Bias :  -1.8148023915484053
# Weight gradient :  -21.247275657417823
# Bias gradient :  -2.1247275657417823
# Weight :  1.268794797138646
# Bias :  -1.8126755371282433
# Weight gradient :  -17.424274817085475
# Bias gradient :  -1.2445910583632482
# Weight :  1.2904884744192668
# Bias :  -1.8114297002329847
# Weight gradient :  41.540888557741724
# Bias gradient :  2.3078271420967624
# Weight :  1.228975943311618
# Bias :  -1.8137398375123608
# Mean loss :  1.4045906408478337
#
# Epoch number:   995
# Weight gradient :  -8.319961793401614
# Bias gradient :  -1.386660298900269
# Weight :  1.237615248377474
# Bias :  -1.8123517891651133
# Weight gradient :  -6.817961572105702
# Bias gradient :  -0.8522451965132127
# Weight :  1.2449066867946366
# Bias :  -1.8114986908703052
# Weight gradient :  -21.240624519909126
# Bias gradient :  -2.1240624519909126
# Weight :  1.268531005023876
# Bias :  -1.8093725022296736
# Weight gradient :  -17.428660882425312
# Bias gradient :  -1.2449043487446652
# Weight :  1.2902301430704117
# Bias :  -1.8081263517304298
# Weight gradient :  41.52451932258998
# Bias gradient :  2.306917740143888
# Weight :  1.228741851046746
# Bias :  -1.8104355786975408
# Mean loss :  1.4032446256797637
#
# Epoch number:   996
# Weight gradient :  -8.308984886271846
# Bias gradient :  -1.384830814378641
# Weight :  1.2373697578812484
# Bias :  -1.8090493616661307
# Weight gradient :  -6.807948880393653
# Bias gradient :  -0.8509936100492066
# Weight :  1.2446504882701774
# Bias :  -1.808197516210626
# Weight gradient :  -21.233978467878103
# Bias gradient :  -2.1233978467878103
# Weight :  1.268267414605266
# Bias :  -1.806071992840468
# Weight gradient :  -17.43304359416784
# Bias gradient :  -1.2452173995834173
# Weight :  1.2899720092424003
# Bias :  -1.8048255289770212
# Weight gradient :  41.50816260339937
# Bias gradient :  2.3060090335221872
# Weight :  1.228507937769449
# Bias :  -1.8071338463278943
# Mean loss :  1.4019008959451518
#
# Epoch number:   997
# Weight gradient :  -8.298016372114773
# Bias gradient :  -1.3830027286857955
# Weight :  1.2371244550877163
# Bias :  -1.8057494592120926
# Weight gradient :  -6.797943844412586
# Bias gradient :  -0.8497429805515733
# Weight :  1.2443944856357991
# Bias :  -1.804898865637967
# Weight gradient :  -21.227337497436256
# Bias gradient :  -2.1227337497436256
# Weight :  1.268004025728599
# Bias :  -1.802774007029615
# Weight gradient :  -17.437422954877107
# Bias gradient :  -1.2455302110626505
# Weight :  1.2897140727842082
# Bias :  -1.8015272300415643
# Weight gradient :  41.491818390600265
# Bias gradient :  2.3051010217000147
# Weight :  1.2282742033428729
# Bias :  -1.8038346384716946
# Mean loss :  1.4005594479761885
#
# Epoch number:   998
# Weight gradient :  -8.287056244513119
# Bias gradient :  -1.3811760407521865
# Weight :  1.2368793398533595
# Bias :  -1.8024520798723431
# Weight gradient :  -6.7879464583089515
# Bias gradient :  -0.8484933072886189
# Weight :  1.2441386787417232
# Bias :  -1.8016027372224046
# Weight gradient :  -21.220701604698284
# Bias gradient :  -2.1220701604698284
# Weight :  1.267740838239775
# Bias :  -1.79947854286758
# Weight gradient :  -17.44179896711541
# Bias gradient :  -1.2458427833653865
# Weight :  1.2894563335449252
# Bias :  -1.7982314529943413
# Weight gradient :  41.47548667463027
# Bias gradient :  2.304193704146126
# Weight :  1.2280406476302677
# Bias :  -1.8005379531986918
# Mean loss :  1.3992202781108165
#
# Epoch number:   999
# Weight gradient :  -8.276104497054487
# Bias gradient :  -1.379350749509081
# Weight :  1.23663441203477
# Bias :  -1.7991572217177016
# Weight gradient :  -6.777956716233589
# Bias gradient :  -0.8472445895291987
# Weight :  1.2438830674382864
# Bias :  -1.7983091290354902
# Weight gradient :  -21.214070785781765
# Bias gradient :  -2.1214070785781765
# Weight :  1.2674778519848127
# Bias :  -1.7961855984263029
# Weight gradient :  -17.446171633443015
# Bias gradient :  -1.246155116674501
# Weight :  1.2891987913737577
# Bias :  -1.7949381959071091
# Weight gradient :  41.45916744593414
# Bias gradient :  2.3032870803296746
# Weight :  1.227807270494988
# Bias :  -1.7972437885801118
# Mean loss :  1.3978833826926995

# %%
#optimal values obtained after training 
print("Optimal value of weight is : ",w)
print("Optimal value of bias is : ",b)
# Out:
# Optimal value of weight is :  1.227807270494988
# Optimal value of bias is :  -1.7972437885801118

# %%
#then the prediction of the nodel after training
print("[8,9,11,16,12] diameter pizza costs : ",predict(np.array([8,9,11,16,12]))," dollars")
# Out:
# [8,9,11,16,12] diameter pizza costs :  [ 8.02521438  9.25302165 11.70863619 17.84767254 12.93644346]  dollars

# %%
#plot to show the relationship between error and weight 
plt.plot(weight_list,loss_list,'r',label="loss point",markersize=15)
plt.title("Relationship between error and weight ")
plt.xlabel("$WEIGHT$")
plt.ylabel("$ERROR$")
plt.grid(True)
plt.legend()
plt.show()

# %%
#plot the line that fits the model
y = w*diameter + b
plt.plot(diameter,price,'r.',markersize=15)
plt.plot(diameter,y)
plt.xlabel("Diameter")
plt.ylabel("Price")
plt.grid(True)
plt.show()

# %%
#Measuring accuracy # Use r-squared 
# in case of linear regression r-square is the product of the Pearson
# product moment correlation coefficient or Pearson's r
#find the sum of residual

# %%
# find the sum of true_test - observed mean value
sum_observed_test = 0 
y_test = np.array([8,9,11,16,12])
price_pred_test = predict(np.array([8,9,11,16,12]))
price_mean_test = price_pred_test.mean()
for _y in price_pred_test:
    sum_observed_test += (_y - price_mean_test)**2 
    
print("Sum of test difference : ",sum_observed_test)
# Out:
# Sum of observed mean :  58.49141490703768

# %%
# also find the sum of residuals 
# given as true_train - measured(predicted)
sum_true_train = 0
y_test = np.array([11,8.5,15,18,11])
price_pred_test = predict(np.array([8,9,11,16,12]))
for y_ ,y_pred in zip(y_test,price_pred_test):   
    sum_true_train += (y_ - y_pred)**2
print("Sum of train difference : ",sum_true_train)
# Out:
# Sum of train difference :  24.02248378084175

# %%
# Then the accuracy of the model 

r_square = 1-(sum_true_train/sum_observed_test)

print("The model a")

# %% [markdown]
# <h3>Using SciKit Learn library</h3>

# %%
#import LinearRegression from scikit learn
from sklearn.linear_model import LinearRegression
#The training data set
diameter = np.array([[6],[8],[10],[14],[18]])
price = np.array([[7],[9],[13],[17.5],[18]])
#Create and fit the model// fit means finding/calculating the optimal values 
# from the provided training set
#create model
model = LinearRegression()
#fit the model
model.fit(diameter,price)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#optimal values obtained from the model
print("The optimal value of weight : ",model.coef_)
#optimal value of bias
print("The optimal value of bias is : ",model.intercept_)
# Out:
# The optimal value of weight :  [[0.9762931]]
# The optimal value of bias is :  [1.96551724]

# %%
#then the prediction of the nodel after training
print("[8,9,11,16,12] diameter pizza costs : ",predict(np.array([8,9,11,16,12]))," dollars")
# Out:
# [8,9,11,16,12] diameter pizza costs :  [ 8.02521438  9.25302165 11.70863619 17.84767254 12.93644346]  dollars

# %%
#plot the line that fits the model
y = model.coef_*diameter + model.intercept_
plt.plot(diameter,price,'r.',markersize=15)
plt.plot(diameter,y)
plt.xlabel("Diameter")
plt.ylabel("Price")
plt.grid(True)
plt.show()

# %%
#check the model accuracy
#test set
X = np.array([[8],[9],[11],[16],[12]])
y = np.array([[11],[8.5],[15],[18],[11]])
print("The model accuracy is : ",model.score(X,y))
# Out:
# The model accuracy is :  0.6620052929422553

# %% [markdown]
# <h3 style="text-align:center;"><u>MULTILINEAR REGRESSION</u></h3>
